# %% [markdown]
# # File I/O in Python

# %%
f = open("sample.txt", "r") # returns a file object
data = f.read()
print(type(data)) # str
print(data)
f.close()
# Out:
# <class 'str'>
# A normal sample file for Part Five based on File I/O in Python

# %%
# Now using write method on it
f = open("sample.txt", "w")
write = f.write("A normal sample file for Part Five based on File I/O in Python")
print(type(write))
f.close()
# Out:
# <class 'int'>
