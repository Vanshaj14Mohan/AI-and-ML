# %% [markdown]
# # File I/O in Python

# %%
# For read method
f = open("sample.txt", "r") # returns a file object
data = f.read()
print(type(data)) # str
print(data)
f.close()
# Out:
# <class 'str'>
# A normal sample file for Part Five based on File I/O in PythonLanguageSome advanced features as well
# Some advanced features as well

# %%
# Now using write method on it
f = open("sample.txt", "w")
write = f.write("A normal sample file for Part Five based on File I/O in Python")
print(type(write))
f.close()
# Out:
# <class 'int'>

# %%
# Using append mode
f = open("sample.txt", "a")
f.write("\nSome advanced features as well")
f.close()

# %%
# Using x mode
f = open("sample2.txt", "x")
f.write("A new txt file to check more modes")
f.close()

# %%
#using + mode with r,w and a
f = open("sample2.txt", "r+")
f.write("Python Language")
print(f.read())
f.close()
# Out:
# of the file

# %%
# using a+
f = open("sample2.txt", "a+")
f.write("\nThe final part")
print(f.read()) # Nothing will be printed as file pointer is at the end
f.close()

# %%
# using w+
f = open("sample2.txt", "w+")
f.write("The final part of the file")
print(f.read()) # Nothing will be printed as file pointer is at the end
f.close()

# %%
# using with keyword
with open("sample2.txt", "r") as f:
    print(f.read())

# No need to explicitly close the file here, as it's handled by with keyword
# Out:
# Python Language of the file

# %%
f = open("sample3.txt", "x")
f.write("A sample 3 txt file for more operations")
f.close()

# %%
# Now to delete this sample3.txt file
import os
os.remove("sample3.txt")

# %%
# A Word seacrh problem
data = True
line = 1
word = "Python"
with open("word.txt", "r") as f:
    while data:
        data = f.readline()

        if("Python" in data):
            print(f"{word} found at line number {line}")
            break

        print(data)
        line +=1
# Out:
# This is a demo file
#
# to store some words
#
# Python found at line number 3
