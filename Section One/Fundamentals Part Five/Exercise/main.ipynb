# %% [markdown]
# # File I/O Questions

# %%
#1: 
with open("names.txt", "w") as f:
    f.write("John\n")
    f.write("Adam\n")
    f.write("Jackie\n")
    f.write("Thomas\n")
    f.write("Tom\n")

# %%
# Now reading it 
with open("names.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# John
# Adam
# Jackie
# Thomas
# Tom

# %%
# 2:
with open("log.txt", "a") as f:
    f.write("Program runs successfully\n")

# %%
with open("log.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# Program runs successfully
# Program runs successfully
# Program runs successfully

# %%
# 3:
numbers = [5, 10, 15, 20, 25]
new_num = [num for num in numbers if num > 15]
print(new_num)
# Out:
# [20, 25]

# %%
# 4:
import json
city = {
    "New York": 150000,
    "New Jersey": 10000,
    "California": 20000
}

with open("city.json", "w") as f:
    json.dump(city, f)


with open("city.json", "r") as f:
    data = json.load(f)
    for city, population in data.items():
        print(city, " ", population)

new_city = input("Enter a new city")
population = int(input("Enter the population"))

data[new_city] = population

with open("data.json", "w") as f:
    json.dump(data, f)
# Out:
# New York   150000
# New Jersey   10000
# California   20000

# %%
# 5:
try:
    with open("data.json", "r") as f:
        content = f.read()
        print(content)
except FileNotFoundError:
    print("File not found")
# Out:
# {"New York": 150000, "New Jersey": 10000, "California": 20000, "Washington": 250000}
