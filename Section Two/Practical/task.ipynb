# %% [markdown]
# # Global Air Quality Data: Kaggle

# %%
import pandas as pd

# %%
df = pd.read_csv("globalAirQuality.csv")

# %%
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
df.shape
# Out:
# (18000, 15)

# %%
df.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')

# %%
df.tail()
# Out:
#                         timestamp country    city  latitude  longitude  \
# 17995  2025-11-19 13:25:17.554219      CH  Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH  Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH  Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH  Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH  Zurich    47.377      8.542
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 17995  27.899  74.179  41.474  6.677  50.869  1.028  103        7.079
# 17996   2.950  47.988  42.235  2.821  35.551  0.644  105       28.734
# 17997  61.347  72.908  46.976  5.763  66.492  0.947  122       21.951
# 17998  40.722  95.152  32.957  5.524  53.193  0.868   95       24.042
# 17999  25.830  30.411  35.317  4.336  66.246  0.848   88        8.529
#
#        humidity  wind_speed
# 17995    52.443       7.452
# 17996    85.678       4.496
# 17997    72.311       9.660
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  object
#  1   country      18000 non-null  object
#  2   city         18000 non-null  object
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
# Selecting data
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
# For columns selection
df[["country", "city"]].head(10)
# Out:
#   country      city
# 0      US  New York
# 1      US  New York
# 2      US  New York
# 3      US  New York
# 4      US  New York
# 5      US  New York
# 6      US  New York
# 7      US  New York
# 8      US  New York
# 9      US  New York

# %%
# Selecting row data using loc and iloc
df.loc[1]
# Out:
# timestamp      2025-11-04 19:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               32.083
# pm10                               63.043
# no2                                 36.12
# so2                                 4.021
# o3                                 43.536
# co                                  1.075
# aqi                                    90
# temperature                         5.838
# humidity                           80.088
# wind_speed                          8.969
# Name: 1, dtype: object

# %%
df.loc[0:2] #here loc includes last index:
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650

# %%
# using iloc
df.iloc[2]
# Out:
# timestamp      2025-11-04 20:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                                42.25
# pm10                               82.553
# no2                                26.935
# so2                                 9.538
# o3                                  23.32
# co                                  0.977
# aqi                                    84
# temperature                        31.833
# humidity                           62.783
# wind_speed                           9.65
# Name: 2, dtype: object

# %%
df.iloc[0:2] # iloc does not include last index here
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
#
#    wind_speed
# 0       3.725
# 1       8.969

# %%
# for accessing rows & columns together
df.loc[0, "aqi"]
# Out:
# 108

# %%
df.loc[0:3, ["city", "aqi"]]
# Out:
#        city  aqi
# 0  New York  108
# 1  New York   90
# 2  New York   84
# 3  New York  158

# %%
df.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')

# %%
df.iloc[0:3, 2]
# Out:
# 0    New York
# 1    New York
# 2    New York
# Name: city, dtype: object

# %%
df.iloc[0:3, 2:6] # city to pm25
# Out:
#        city  latitude  longitude    pm25
# 0  New York    40.713    -74.006  50.295
# 1  New York    40.713    -74.006  32.083
# 2  New York    40.713    -74.006  42.250

# %%
# selecting single scalar value using at and iat
df.at[0, "country"]
# Out:
# 'US'

# %%
#using iat
df.iat[0, 1]
# Out:
# 'US'

# %%
# Filterind our data
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
df[df["aqi"] > 100 ]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[df["aqi"] > 100 ].head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 6  2025-11-05 00:25:17.554219      US  New York    40.713    -74.006  77.690
# 7  2025-11-05 01:25:17.554219      US  New York    40.713    -74.006  57.816
# 8  2025-11-05 02:25:17.554219      US  New York    40.713    -74.006  60.914
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 6   65.198  20.302  7.641  62.687  0.734  155       36.729    47.651
# 7  111.709  34.533  6.945  41.304  0.771  115       37.891    53.314
# 8   44.775  40.936  6.779  36.751  1.014  121       24.092    48.148
#
#    wind_speed
# 0       3.725
# 3       8.956
# 6       4.542
# 7       7.605
# ...

# %%
# using mutliple conditions
df[(df["aqi"] > 100) & (df["temperature"] > 30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17947  2025-11-17 13:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17975  2025-11-18 17:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[(df["aqi"] > 100) & (df["temperature"] < 30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# 12     2025-11-05 06:25:17.554219      US  New York    40.713    -74.006
# 13     2025-11-05 07:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17988  2025-11-19 06:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
# can do chaining of conditions as well
df[(df["aqi"] > 100)] [["city", "aqi", "temperature"]] # printing just 3 columns
# Out:
#            city  aqi  temperature
# 0      New York  108       18.504
# 3      New York  158       23.140
# 6      New York  155       36.729
# 7      New York  115       37.891
# 8      New York  121       24.092
# ...         ...  ...          ...
# 17991    Zurich  104       32.556
# 17993    Zurich  153       20.437
# 17995    Zurich  103        7.079
# 17996    Zurich  105       28.734
# 17997    Zurich  122       21.951
#
# [9721 rows x 3 columns]

# %%
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
# Query methods
# Query returns a copy not a view
df.query("aqi > 200")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 745    2025-11-05 19:25:17.554219      GB    London    51.507     -0.128
# 8941   2025-11-17 07:25:17.554219      JP     Osaka    34.694    135.502
# 12956  2025-11-19 14:25:17.554219      NZ  Auckland   -36.848    174.763
# 14555  2025-11-11 05:25:17.554219      PH    Manila    14.600    120.984
# 17458  2025-11-12 04:25:17.554219      FI  Helsinki    60.170     24.938
# 17529  2025-11-15 03:25:17.554219      FI  Helsinki    60.170     24.938
# 17815  2025-11-12 01:25:17.554219      CH    Zurich    47.377      8.542
#
#           pm25    pm10     no2     so2      o3     co  aqi  temperature  \
# 745    107.144  43.819  13.389   4.601  21.680  0.890  214       19.055
# 8941   102.142  95.204  41.688   7.806  28.951  0.753  204       15.277
# 12956   44.824  66.657  90.019   3.637  41.311  0.849  225       14.872
# 14555  103.023  66.678  43.284   2.167  48.250  0.849  206       11.027
# ...

# %%
df.query("aqi > 190 & temperature > 30")
# Out:
#                         timestamp country         city  latitude  longitude  \
# 112    2025-11-09 10:25:17.554219      US     New York    40.713    -74.006
# 3115   2025-11-14 13:25:17.554219      MX  Mexico City    19.433    -99.133
# 6747   2025-11-15 21:25:17.554219      IN       Mumbai    19.076     72.878
# 6783   2025-11-17 09:25:17.554219      IN       Mumbai    19.076     72.878
# 7024   2025-11-12 10:25:17.554219      IN        Delhi    28.704     77.102
# 8841   2025-11-13 03:25:17.554219      JP        Osaka    34.694    135.502
# 11564  2025-11-06 14:25:17.554219      ID      Jakarta    -6.209    106.846
# 11891  2025-11-05 05:25:17.554219      AU       Sydney   -33.869    151.209
# 12776  2025-11-12 02:25:17.554219      NZ     Auckland   -36.848    174.763
# 17458  2025-11-12 04:25:17.554219      FI     Helsinki    60.170     24.938
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.query("aqi > 190 & temperature > 30")[["city", "aqi"]] #doing chaining
# Out:
#               city  aqi
# 112       New York  192
# 3115   Mexico City  196
# 6747        Mumbai  194
# 6783        Mumbai  191
# 7024         Delhi  195
# 8841         Osaka  191
# 11564      Jakarta  198
# 11891       Sydney  193
# 12776     Auckland  196
# 17458     Helsinki  202

# %%
aqi_val = 100
df.query("aqi > @aqi_val & temperature > 30")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17947  2025-11-17 13:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17975  2025-11-18 17:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.isnull().sum()
# Out:
# timestamp      0
# country        0
# city           0
# latitude       0
# longitude      0
# pm25           0
# pm10           0
# no2            0
# so2            0
# o3             0
# co             0
# aqi            0
# temperature    0
# humidity       0
# wind_speed     0
# dtype: int64

# %%
df.isnull().sum().plot(kind="bar", figsize=(6,4))
# Out:
# <Axes: >
