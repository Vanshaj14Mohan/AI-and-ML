# %% [markdown]
# ## Pandas Introduction

# %%
import pandas as pd

# %%
info = {
    "Name:": ["John", "David", "Thomas"],
    "CGPA:": [8.9, 9.0, 8.5]
}

df = pd.DataFrame(info)
print(df)
# Out:
#     Name:  CGPA:
# 0    John    8.9
# 1   David    9.0
# 2  Thomas    8.5

# %%
df
# Out:
#     Name:  CGPA:
# 0    John    8.9
# 1   David    9.0
# 2  Thomas    8.5
