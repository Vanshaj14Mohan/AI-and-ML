# %% [markdown]
# ## Scraping Activity

# %% [markdown]
# ### Quotes Data Scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
# url = "https://quotes.toscrape.com/page/1/"
page_count = 1 # would show response 200 but actually the page doesn't exist

while True:
    url = f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(url) # Now let's see how long the requests are going in

    soup = BeautifulSoup(res.text, "lxml")
    quotes = soup.select("div.quote")
    # print(quotes)
    # print(res)

    if not quotes:
        print("No valid pages anymore")
        break

    with open(f"Scrapped Data/quotes{page_count}.html", "w", encoding="utf-8") as f:
        f.write(res.text)
        print(f"Downloaded pages from page {page_count}")

    page_count = page_count + 1
# Checking for valid-non-valid data
# Out:
# Downloaded pages from page 1
# Downloaded pages from page 2
# Downloaded pages from page 3
# Downloaded pages from page 4
# Downloaded pages from page 5
# Downloaded pages from page 6
# Downloaded pages from page 7
# Downloaded pages from page 8
# Downloaded pages from page 9
# Downloaded pages from page 10
# No valid pages anymore
